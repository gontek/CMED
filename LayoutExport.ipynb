# %%
import os
aprx = arcpy.mp.ArcGISProject(r"CURRENT")  #"CURRENT" can also be used to replace the path
lyt = aprx.listLayouts() #x: The number of the layout within the project

for layout in lyt:
    print(layout.name)
#    lyt.exportToPDF(os.path.join(r"\\citydata\users\kgonterwitz\projectreviews\test", f"{layout.name}"))
#print("Export Succeeded")
# Out:
# Lawrence Reference
# Map 5B - T2050- Baldwin City Land Form and Barriers
# Map 5C - T2050 - Lecompton Land Form and Barriers
# Map 8 - T2050 - Environmental Justice
# Map 9 - T2050 - Lawrence Existing Bikeways
# Map 9A - T2050 - DGCO Existing Bikeways
# Map 10BCD - T2050 - DGCO Cities Existing Sidewalk Conditions
# Map 12 - T2050 - Lawrence Transit System
# Map 12C - T2050 - Lawrence Transit System - Buffer
# Map 12D - T2050 - Lawrence Transit System - Zero Vehicle HH
# Map 13 - T2050 - DGCO Functional Classification
# Map 9B - T2050 - Lawrence Bikeways - Speed Limit Reductions
# Map 14 - T2050 - Major Thoroughfares
# Map 12B - T2050 - Lawrence Transit System - Highest Boarding
# Map 17 - T2050 - Lawrence Signalized Intersections
# Map 20 - T2050 - Lawrence Pavement Conditions Index Map
# Map 21 - T2050 - DGCO Railroads and Highways Map
# Map 25C - T2050 - Historic Conservation
# Map 25C - T2050 - Historic Conservation with projects
# Map 25D - T2050 - T&E Species
# Map 27 - T2050 - DGCO - Bike Crashes
# Map 27 - T2050 - DGCO - Pedestrian Crashes
# Map 9C - T2050 - Lawrence Bikeways - LOC Change
# Map 27 - T2050 - DGCO - Vehicle Crashes
# Map 27A - T2050 - Lawrence - Bike Crashes
# Map 27A - T2050 - Lawrence - Pedestrian Crashes
# Map 27A - T2050 - Lawrence - Vehicle Crashes
# Map 27BCD - T2050 - Other Cities - Bike Crashes
# Map 27BCD - T2050 - Other Cities - Pedestrian Crashes
# Map 27BCD - T2050 - Other Cities - Vehicle Crashes
# Map 28A - T2050 - Projects - Bikeways - County
# Map 28A - T2050 - Projects - Bikeways - Lawrence
# Map 10 - T2050 - Lawrence Missing Sidewalk
# County Reference
# Map 10A - T2050 - Existing Sidewalk Conditions
# Map 28 - T2050 - Projects - Roads and Bridges
# Map 28 - T2050 - Projects - Sidewalk Conditions
# Map 25 - T2050 - Conservation and Historic Zones
# Map 25B - T2050 - Conservation
# Map 25E - T2050 - Conservation - Soils w projects
# Map 25F - T2050 - Conservation - Water w projects
# Map 28A - T2050 - Projects - Pedestrians
# Map 28BCD - T2050 - Projects - Pedestrian - DGCO
# Map 18 - T2050 - Lawrence Gateways
# Map 1 - T2050 - DGCO Planning Area Boundaries
# Map 18B - T2050 - DGCO Gateways
# Map 6 - T2050 - Population Change
# Map 7 - T2050 - Population Projection
# Map 22 - T2050 - Lawrence Critical Freight Corridors
# Map 23 - T2050 - Lawrence Traffic Flow
# Map 24 - T2050 - DGCO Bridges
# Map 12E - T2050 - Lawrence Transit System - Wheelchair Accessibility
# Map 12F - T2050 - Lawrence Transit System - Bench Accessibility
# Map 12G - T2050 - Lawrence Transit System - Bike Rack Accessibility
# Map 12H - T2050 - Lawrence Transit System - Shelter Accessibility
# Map 2 - T2050 - DGCO Land Use
# Map 12I - T2050 - Lawrence Transit System - Half-Fare
# BC, Eud, Lecompton Reference
# Map 17A - T2050 - Lawrence Coordinated Traffic Signals
# Layout
# Map 3 - T2050 - Lawrence Land Use
# Map 4 - T2050 - Lawrence Land Form and Barriers
# Map 5 - T2050 - Eudora Land Form and Barriers
# Map 29 - T2050 - Commuting Patterns 1
# Map 24 - T2050 - DGCO Bridges1
# Map 25C - T2050 - Historic Conservation update
# Map 25C - T2050 - Historic Conservation1
# Map 27R - T2050 - DGCO - Vehicle Crash Rates
# Map 27BCD - T2050 - Other Cities - Vehicle Crash Rates
# Map 27R - T2050 - Lawrence - Vehicle Crash Rates
# Map 28 - T2050 - Projects - Roads and Bridges t2050 update
# Map 28 - T2050 - Projects - Sidewalk Conditions t2050 update
# Map 9D - T2050 - Bikeways LOC
# Map 29 - T2050 - Commuting Patterns
# Mapped Projects Located In the EJ Zone Lawrence
# Mapped Projects and Transportation Disadvantaged Populations Lawrence
# Layout1
# Layout2
# Layout3
# Layout4

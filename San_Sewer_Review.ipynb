# %%
arcpy.env.overwriteOutput = True

arcpy.analysis.Buffer(r"Model\Junctions", "Junctions_Buffer", "2 Feet", "FULL", "ROUND", "NONE", None, "PLANAR")

arcpy.analysis.Intersect(r"Junctions_Buffer #;SewerCollector\ssManhole #", "Junctions_Intersect_Manholes", "ALL", None, "POINT")
# Out:
# <Result 'C:\\Users\\kgonterwitz\\OneDrive - City of Lawrence KS\\Documents\\ArcGIS\\Projects\\PlanningMapsKyle.gdb\\Junctions_Intersect_Manholes'>

# %%
#Manhole ID

arcpy.management.MakeFeatureLayer("Junctions_Intersect_Manholes", "Manhole ID discrepancy", "NAME <> FACILITYID", None, "OBJECTID OBJECTID HIDDEN NONE;Shape Shape HIDDEN NONE;FID_Junctions_Buffer FID_Junctions_Buffer HIDDEN NONE;NAME NAME VISIBLE NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV INVERTELEV HIDDEN NONE;RIMELEV RIMELEV HIDDEN NONE;DEPTH DEPTH HIDDEN NONE;INITDEPTH INITDEPTH HIDDEN NONE;SURCHDEPTH SURCHDEPTH HIDDEN NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE;BUFF_DIST BUFF_DIST HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FACILITYABBV FACILITYABBV HIDDEN NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE HIDDEN NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV_1 RIMELEV_1 HIDDEN NONE;INVERT INVERT HIDDEN NONE;HIGHELEV HIGHELEV HIDDEN NONE;INVERTELEV_1 INVERTELEV_1 HIDDEN NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;SHEET SHEET HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE")
# Out:
# <Result 'Manhole ID discrepancy'>

# %%
#Invert Elevation compare GIS to model;

arcpy.management.MakeFeatureLayer("Junctions_Intersect_Manholes", "Manhole Invert Discrepancy", 'Round(INVERTELEV, 2) <> Round(INVERTELEV_1, 2)', None, "OBJECTID OBJECTID HIDDEN NONE;Shape Shape HIDDEN NONE;FID_Junctions_Buffer FID_Junctions_Buffer HIDDEN NONE;NAME NAME VISIBLE NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV INVERTELEV VISIBLE NONE;RIMELEV RIMELEV HIDDEN NONE;DEPTH DEPTH HIDDEN NONE;INITDEPTH INITDEPTH HIDDEN NONE;SURCHDEPTH SURCHDEPTH HIDDEN NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE;BUFF_DIST BUFF_DIST HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FACILITYABBV FACILITYABBV HIDDEN NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE HIDDEN NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV_1 RIMELEV_1 HIDDEN NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV VISIBLE NONE;INVERTELEV_1 INVERTELEV_1 VISIBLE NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;LINED LINED VISIBLE NONE;LINEDYEAR LINEDYEAR VISIBLE NONE;CONDITION CONDITION VISIBLE NONE;VERIFICATION VERIFICATION HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;SHEET SHEET HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;created_user created_user VISIBLE NONE;created_date created_date VISIBLE NONE;last_edited_user last_edited_user VISIBLE NONE;last_edited_date last_edited_date VISIBLE NONE")
# Out:
# <Result 'Manhole Invert Discrepancy'>

# %%
#Check GIS pipe facility ID matches US-DS MH Logic
#City GIS Only Check

arcpy.management.FeatureVerticesToPoints(r"SewerCollector\ssGravityMain", "ssGravityMain_StartPoint", "START")
arcpy.management.FeatureVerticesToPoints(r"SewerCollector\ssGravityMain", "ssGravityMain_EndPoint", "END")
arcpy.management.FeatureVerticesToPoints(r"SewerCollector\ssGravityMain", "ssGravityMain_MidPoint", "MID")

arcpy.management.CalculateField("ssGravityMain_MidPoint", "FacID_FROM", "!FACILITYID!.split(' - ')[0]", "PYTHON3", '', "TEXT", "NO_ENFORCE_DOMAINS")
arcpy.management.CalculateField("ssGravityMain_MidPoint", "FacID_TO", "!FACILITYID!.split(' - ')[-1]", "PYTHON3", '', "TEXT", "NO_ENFORCE_DOMAINS")

arcpy.management.MakeFeatureLayer("ssGravityMain_MidPoint", "ssGravityMain_US_Facility_ID_MH_Discrepancy", "FROMMH <> FacID_FROM", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH HIDDEN NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM VISIBLE NONE;FacID_TO FacID_TO HIDDEN NONE")
arcpy.management.MakeFeatureLayer("ssGravityMain_MidPoint", "ssGravityMain_DS_Facility_ID_MH_Discrepancy", "TOMH <> FacID_TO", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH HIDDEN NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO VISIBLE NONE")
# Out:
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# <Result 'ssGravityMain_DS_Facility_ID_MH_Discrepancy'>

# %%
#Spatial Join between GIS Gravity Mains and Model Conduits for comparison
arcpy.env.overwriteOutput = True
arcpy.analysis.SpatialJoin("ssGravityMain_MidPoint", r"Model\Conduits", "GravityMainModelJoin","JOIN_ONE_TO_ONE", "KEEP_ALL", "#", "INTERSECT", "1 Feet", '')
# Out:
# <Result 'C:\\Users\\kgonterwitz\\OneDrive - City of Lawrence KS\\Documents\\ArcGIS\\Projects\\PlanningMapsKyle.gdb\\GravityMainModelJoin'>

# %%
#Validate GIS elevations between manholes and gravity pipes

#arcpy.analysis.Intersect(r"ssGravityMain_StartPoint #;SewerCollector\ssManhole #", "ssGravityMain_US_MH_EL", "ALL", None, "POINT")
arcpy.analysis.Intersect(r"ssGravityMain_EndPoint #;SewerCollector\ssManhole #", "ssGravityMain_DS_MH_EL", "ALL", None, "POINT")

#check Z connectivity of Upstream Pipe and Manhole Inverts
arcpy.management.MakeFeatureLayer("ssGravityMain_US_MH_EL", "GIS_PipeUpstreamHigherThanMH", "(UPELEV - INVERTELEV)>0.1", None, "OBJECTID OBJECTID HIDDEN NONE;SHAPE SHAPE HIDDEN NONE;FID_ssGravityMain_StartPoint FID_ssGravityMain_StartPoint HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE VISIBLE NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID_1 FACILITYID_1 VISIBLE NONE;FACILITYABBV FACILITYABBV HIDDEN NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE VISIBLE NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV RIMELEV HIDDEN NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV HIDDEN NONE;INVERTELEV INVERTELEV VISIBLE NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE_1 INSTALLDATE_1 HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR_1 LINEDYEAR_1 HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION_1 VERIFICATION_1 HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED_1 ENABLED_1 HIDDEN NONE;ACTIVEFLAG_1 ACTIVEFLAG_1 HIDDEN NONE;OWNEDBY_1 OWNEDBY_1 HIDDEN NONE;MAINTBY_1 MAINTBY_1 HIDDEN NONE;SUMFLOW_1 SUMFLOW_1 HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE_1 WATERTYPE_1 HIDDEN NONE;PROJECT_1 PROJECT_1 HIDDEN NONE;SHEET_1 SHEET_1 HIDDEN NONE;CONTRACTEDBY_1 CONTRACTEDBY_1 HIDDEN NONE;ENGINEEREDBY_1 ENGINEEREDBY_1 HIDDEN NONE;LIFECYCLESTATUS_1 LIFECYCLESTATUS_1 HIDDEN NONE;SERIALNO_LOTNO_1 SERIALNO_LOTNO_1 HIDDEN NONE;HYPERLINK_1 HYPERLINK_1 HIDDEN NONE;COMMENTS_1 COMMENTS_1 HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE_1 LASTUPDATE_1 HIDDEN NONE;LASTEDITOR_1 LASTEDITOR_1 HIDDEN NONE;VERSIONNAME_1 VERSIONNAME_1 HIDDEN NONE;created_user_1 created_user_1 HIDDEN NONE;created_date_1 created_date_1 HIDDEN NONE;last_edited_user_1 last_edited_user_1 HIDDEN NONE;last_edited_date_1 last_edited_date_1 HIDDEN NONE")
arcpy.management.MakeFeatureLayer("ssGravityMain_US_MH_EL", "GIS_PipeUpstreamLowerThanMH", "(INVERTELEV-UPELEV)>0.1", None, "OBJECTID OBJECTID HIDDEN NONE;SHAPE SHAPE HIDDEN NONE;FID_ssGravityMain_StartPoint FID_ssGravityMain_StartPoint HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE VISIBLE NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID_1 FACILITYID_1 VISIBLE NONE;FACILITYABBV FACILITYABBV HIDDEN NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE VISIBLE NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV RIMELEV HIDDEN NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV HIDDEN NONE;INVERTELEV INVERTELEV VISIBLE NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE_1 INSTALLDATE_1 HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR_1 LINEDYEAR_1 HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION_1 VERIFICATION_1 HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED_1 ENABLED_1 HIDDEN NONE;ACTIVEFLAG_1 ACTIVEFLAG_1 HIDDEN NONE;OWNEDBY_1 OWNEDBY_1 HIDDEN NONE;MAINTBY_1 MAINTBY_1 HIDDEN NONE;SUMFLOW_1 SUMFLOW_1 HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE_1 WATERTYPE_1 HIDDEN NONE;PROJECT_1 PROJECT_1 HIDDEN NONE;SHEET_1 SHEET_1 HIDDEN NONE;CONTRACTEDBY_1 CONTRACTEDBY_1 HIDDEN NONE;ENGINEEREDBY_1 ENGINEEREDBY_1 HIDDEN NONE;LIFECYCLESTATUS_1 LIFECYCLESTATUS_1 HIDDEN NONE;SERIALNO_LOTNO_1 SERIALNO_LOTNO_1 HIDDEN NONE;HYPERLINK_1 HYPERLINK_1 HIDDEN NONE;COMMENTS_1 COMMENTS_1 HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE_1 LASTUPDATE_1 HIDDEN NONE;LASTEDITOR_1 LASTEDITOR_1 HIDDEN NONE;VERSIONNAME_1 VERSIONNAME_1 HIDDEN NONE;created_user_1 created_user_1 HIDDEN NONE;created_date_1 created_date_1 HIDDEN NONE;last_edited_user_1 last_edited_user_1 HIDDEN NONE;last_edited_date_1 last_edited_date_1 HIDDEN NONE")

#check Z connectivity of Downstream Pipe and Manhole Inverts 
arcpy.management.MakeFeatureLayer("ssGravityMain_DS_MH_EL", "GIS_PipeDownstreamLowerThanMH", "(INVERTELEV-DOWNELEV)>0.1", None, "OBJECTID OBJECTID HIDDEN NONE;SHAPE SHAPE HIDDEN NONE;FID_ssGravityMain_EndPoint FID_ssGravityMain_EndPoint HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV VISIBLE NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID_1 FACILITYID_1 VISIBLE NONE;FACILITYABBV FACILITYABBV HIDDEN NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE VISIBLE NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV RIMELEV HIDDEN NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV VISIBLE NONE;INVERTELEV INVERTELEV VISIBLE NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE_1 INSTALLDATE_1 HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR_1 LINEDYEAR_1 HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION_1 VERIFICATION_1 HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED_1 ENABLED_1 HIDDEN NONE;ACTIVEFLAG_1 ACTIVEFLAG_1 HIDDEN NONE;OWNEDBY_1 OWNEDBY_1 HIDDEN NONE;MAINTBY_1 MAINTBY_1 HIDDEN NONE;SUMFLOW_1 SUMFLOW_1 HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE_1 WATERTYPE_1 HIDDEN NONE;PROJECT_1 PROJECT_1 HIDDEN NONE;SHEET_1 SHEET_1 HIDDEN NONE;CONTRACTEDBY_1 CONTRACTEDBY_1 HIDDEN NONE;ENGINEEREDBY_1 ENGINEEREDBY_1 HIDDEN NONE;LIFECYCLESTATUS_1 LIFECYCLESTATUS_1 HIDDEN NONE;SERIALNO_LOTNO_1 SERIALNO_LOTNO_1 HIDDEN NONE;HYPERLINK_1 HYPERLINK_1 HIDDEN NONE;COMMENTS_1 COMMENTS_1 HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE_1 LASTUPDATE_1 HIDDEN NONE;LASTEDITOR_1 LASTEDITOR_1 HIDDEN NONE;VERSIONNAME_1 VERSIONNAME_1 HIDDEN NONE;created_user_1 created_user_1 HIDDEN NONE;created_date_1 created_date_1 HIDDEN NONE;last_edited_user_1 last_edited_user_1 HIDDEN NONE;last_edited_date_1 last_edited_date_1 HIDDEN NONE")
# Out:
# <Result 'C:\\Users\\kgonterwitz\\OneDrive - City of Lawrence KS\\Documents\\ArcGIS\\Projects\\PlanningMapsKyle.gdb\\ssGravityMain_DS_MH_EL'>

# %%
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "ModelDuplicateConduit", "Join_Count > 1", None, "#")
arcpy.management.SelectLayerByLocation(r"Model\Conduits", "INTERSECT", "ModelDuplicateConduit", "1 Feet", "NEW_SELECTION", "NOT_INVERT")
arcpy.management.MakeFeatureLayer(r"Model\Conduits", "Conduits_DuplicateGeometry", '', None, "#")
arcpy.management.SelectLayerByAttribute(r"Model\Conduits", "CLEAR_SELECTION", '', None)
# Out:
# <Result 'Model\\Conduits'>

# %%
#Check Model Diameters vs GIS

arcpy.management.CalculateField("GravityMainModelJoin", "ModelDiameterInches", "round(!GEOM1!*12, 0)", "PYTHON3", '', "DOUBLE", "NO_ENFORCE_DOMAINS")
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Diameter_Conduit_GIS_Discrepancy", "DIAMETER <> ModelDiameterInches", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV VISIBLE NONE;SLOPE SLOPE VISIBLE NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM VISIBLE NONE;FacID_TO FacID_TO VISIBLE NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT VISIBLE NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION VISIBLE NONE;GEOM1 GEOM1 VISIBLE NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate VISIBLE NONE;ModelDiameterInches ModelDiameterInches VISIBLE NONE")
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Diameter_Conduit_GIS_Discrepancy", "DIAMETER <> ModelDiameterInches", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE VISIBLE NONE;DIAMETER DIAMETER VISIBLE NONE;MATERIAL MATERIAL VISIBLE NONE;PIPECLASS PIPECLASS VISIBLE NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV VISIBLE NONE;SLOPE SLOPE VISIBLE NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM VISIBLE NONE;FacID_TO FacID_TO VISIBLE NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT VISIBLE NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION VISIBLE NONE;GEOM1 GEOM1 VISIBLE NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate VISIBLE NONE;ModelDiameterInches ModelDiameterInches VISIBLE NONE")

# %%
#Check model slope vs GIS
#GIS number is in grade (slope * 100), model conduit is actual slope
arcpy.management.CalculateField("GravityMainModelJoin", "SlopeCheck", "abs(!SLOPE!/100-!SLOPE_1!)", "PYTHON3", '', "DOUBLE", "NO_ENFORCE_DOMAINS")
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Conduit_Slope_Tolerance_gt001", "SlopeCheck >= 0.01", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE VISIBLE NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE VISIBLE NONE;DIAMETER DIAMETER VISIBLE NONE;MATERIAL MATERIAL VISIBLE NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV VISIBLE NONE;SLOPE SLOPE VISIBLE NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO HIDDEN NONE;NAME NAME HIDDEN NONE;INLETNODE INLETNODE HIDDEN NONE;OUTLETNODE OUTLETNODE HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET VISIBLE NONE;OUTOFFSET OUTOFFSET VISIBLE NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 VISIBLE NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ModelDiameterInches ModelDiameterInches VISIBLE NONE;SlopeCheck SlopeCheck VISIBLE NONE")

# %%
#Check US/DS conduit elevations vs GIS
arcpy.management.CalculateField("GravityMainModelJoin", "DownStreamElevationCheck", "abs(!DOWNELEV!-!OUTOFFSET!)", "PYTHON3", '', "DOUBLE", "NO_ENFORCE_DOMAINS")
arcpy.management.CalculateField("GravityMainModelJoin", "UpStreamElevationCheck", "abs(!UPELEV!-!INOFFSET!)", "PYTHON3", '', "DOUBLE", "NO_ENFORCE_DOMAINS")

arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Conduit_Upstream_Elevation_Discrepancy_gt001", "UpStreamElevationCheck >= 0.01", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE VISIBLE NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO HIDDEN NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET VISIBLE NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ModelDiameterInches ModelDiameterInches HIDDEN NONE;SlopeCheck SlopeCheck VISIBLE NONE;UpStreamElevationCheck UpStreamElevationCheck VISIBLE NONE;DownStreamElevationCheck DownStreamElevationCheck HIDDEN NONE")
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Conduit_Dnstream_Elevation_Discrepancy_gt001", "DownStreamElevationCheck >= 0.01", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE VISIBLE NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE VISIBLE NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV VISIBLE NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO HIDDEN NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET VISIBLE NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ModelDiameterInches ModelDiameterInches HIDDEN NONE;SlopeCheck SlopeCheck HIDDEN NONE;UpStreamElevationCheck UpStreamElevationCheck HIDDEN NONE;DownStreamElevationCheck DownStreamElevationCheck VISIBLE NONE")

# %%
#Check model conduit ID matches from-to Logic within model fields, not comparing to GIS


arcpy.management.CalculateField("GravityMainModelJoin", "NAME_FROM", "!NAME!.split('_-_')[0]", "PYTHON3", '', "TEXT", "NO_ENFORCE_DOMAINS")
arcpy.management.CalculateField("GravityMainModelJoin", "NAME_TO", "!NAME!.split('_-_')[-1]", "PYTHON3", '', "TEXT", "NO_ENFORCE_DOMAINS")

arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Conduit_MHF_Discrepancy", "INLETNODE <> NAME_FROM Or INLETNODE IS NULL Or NAME_FROM IS NULL", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH HIDDEN NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO HIDDEN NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ModelDiameterInches ModelDiameterInches HIDDEN NONE;SlopeCheck SlopeCheck HIDDEN NONE;UpStreamElevationCheck UpStreamElevationCheck HIDDEN NONE;DownStreamElevationCheck DownStreamElevationCheck HIDDEN NONE;NAME_FROM NAME_FROM VISIBLE NONE;NAME_TO NAME_TO HIDDEN NONE")
arcpy.management.MakeFeatureLayer("GravityMainModelJoin", "Conduit_MHT_Discrepancy", "OUTLETNODE <> NAME_TO Or OUTLETNODE IS NULL Or NAME_TO IS NULL", None, "OBJECTID OBJECTID VISIBLE NONE;SHAPE SHAPE HIDDEN NONE;Join_Count Join_Count HIDDEN NONE;TARGET_FID TARGET_FID HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH HIDDEN NONE;TOMH TOMH VISIBLE NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV HIDDEN NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FacID_FROM FacID_FROM HIDDEN NONE;FacID_TO FacID_TO VISIBLE NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE HIDDEN NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ModelDiameterInches ModelDiameterInches HIDDEN NONE;SlopeCheck SlopeCheck HIDDEN NONE;UpStreamElevationCheck UpStreamElevationCheck HIDDEN NONE;DownStreamElevationCheck DownStreamElevationCheck HIDDEN NONE;NAME_FROM NAME_FROM HIDDEN NONE;NAME_TO NAME_TO VISIBLE NONE")
# Out:
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# AttributeError: 'NoneType' object has no attribute 'split'
# Traceback (most recent call last):
#   File "<expression>", line 1, in <module>
# ...

# %%
#Check model conduit elevations vs model junction elevations
arcpy.management.FeatureVerticesToPoints(r"Model\Conduits", "Conduits_StartPoint", "START")
arcpy.management.FeatureVerticesToPoints(r"Model\Conduits", "Conduits_EndPoint", "END")
arcpy.management.FeatureVerticesToPoints(r"Model\Conduits", "Conduits_MidPoint", "MID")

#Validate model elevations between junctions and conduits

arcpy.analysis.Intersect(r"Conduits_StartPoint #;Model\Junctions #", "Conduit_US_Jct_EL", "ALL", None, "POINT")
arcpy.analysis.Intersect(r"Conduits_EndPoint #;Model\Junctions #", "Conduit_DS_Jct_EL", "ALL", None, "POINT")

arcpy.management.MakeFeatureLayer("Conduit_DS_Jct_EL", "Conduit_DS_Jct_EL_Zundershoot", "(INVERTELEV-OUTOFFSET )>0.01", None, "OBJECTID OBJECTID HIDDEN NONE;Shape Shape HIDDEN NONE;FID_Conduits_EndPoint FID_Conduits_EndPoint HIDDEN NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET VISIBLE NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen HIDDEN NONE;Concate Concate HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_Junctions FID_Junctions HIDDEN NONE;NAME_1 NAME_1 VISIBLE NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT_1 DESCRIPT_1 HIDDEN NONE;TAG_1 TAG_1 HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV INVERTELEV VISIBLE NONE;RIMELEV RIMELEV VISIBLE NONE;DEPTH DEPTH VISIBLE NONE;INITDEPTH INITDEPTH VISIBLE NONE;SURCHDEPTH SURCHDEPTH VISIBLE NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA_1 TOTCONAREA_1 HIDDEN NONE;IMPCONAREA_1 IMPCONAREA_1 HIDDEN NONE;UNITFLOW_1 UNITFLOW_1 HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE")
arcpy.management.MakeFeatureLayer("Conduit_US_Jct_EL", "Conduit_US_Jct_EL_Zundershoot", "(INVERTELEV-INOFFSET )>0.01", None, "OBJECTID OBJECTID HIDDEN NONE;Shape Shape HIDDEN NONE;FID_Conduits_StartPoint FID_Conduits_StartPoint HIDDEN NONE;NAME NAME VISIBLE NONE;INLETNODE INLETNODE VISIBLE NONE;OUTLETNODE OUTLETNODE VISIBLE NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET VISIBLE NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_Junctions FID_Junctions HIDDEN NONE;NAME_1 NAME_1 HIDDEN NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT_1 DESCRIPT_1 HIDDEN NONE;TAG_1 TAG_1 HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV INVERTELEV VISIBLE NONE;RIMELEV RIMELEV VISIBLE NONE;DEPTH DEPTH VISIBLE NONE;INITDEPTH INITDEPTH VISIBLE NONE;SURCHDEPTH SURCHDEPTH HIDDEN NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA_1 TOTCONAREA_1 HIDDEN NONE;IMPCONAREA_1 IMPCONAREA_1 HIDDEN NONE;UNITFLOW_1 UNITFLOW_1 HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE")
# Out:
# <Result 'C:\\Users\\kgonterwitz\\OneDrive - City of Lawrence KS\\Documents\\ArcGIS\\Projects\\PlanningMapsKyle.gdb\\Conduit_DS_Jct_EL'>

# %%
#check model conduits vs GIS gravity pipe elevations

arcpy.analysis.Intersect("ssGravityMain_US_MH_EL #;Conduit_US_Jct_EL #", "GISModel_US", "ALL", None, "INPUT")
arcpy.management.MakeFeatureLayer("GISModel_US", "GISModel_US_Layer", "abs(UPELEV - INOFFSET)>0.1", None, "OBJECTID OBJECTID HIDDEN NONE;SHAPE SHAPE HIDDEN NONE;FID_ssGravityMain_US_MH_EL FID_ssGravityMain_US_MH_EL HIDDEN NONE;FID_ssGravityMain_StartPoint FID_ssGravityMain_StartPoint HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH HIDDEN NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID_1 FACILITYID_1 VISIBLE NONE;FACILITYABBV FACILITYABBV VISIBLE NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE VISIBLE NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV RIMELEV VISIBLE NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV VISIBLE NONE;INVERTELEV INVERTELEV HIDDEN NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE_1 INSTALLDATE_1 HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR_1 LINEDYEAR_1 HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION_1 VERIFICATION_1 HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED_1 ENABLED_1 HIDDEN NONE;ACTIVEFLAG_1 ACTIVEFLAG_1 HIDDEN NONE;OWNEDBY_1 OWNEDBY_1 HIDDEN NONE;MAINTBY_1 MAINTBY_1 HIDDEN NONE;SUMFLOW_1 SUMFLOW_1 HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE_1 WATERTYPE_1 HIDDEN NONE;PROJECT_1 PROJECT_1 HIDDEN NONE;SHEET_1 SHEET_1 HIDDEN NONE;CONTRACTEDBY_1 CONTRACTEDBY_1 HIDDEN NONE;ENGINEEREDBY_1 ENGINEEREDBY_1 HIDDEN NONE;LIFECYCLESTATUS_1 LIFECYCLESTATUS_1 HIDDEN NONE;SERIALNO_LOTNO_1 SERIALNO_LOTNO_1 HIDDEN NONE;HYPERLINK_1 HYPERLINK_1 HIDDEN NONE;COMMENTS_1 COMMENTS_1 HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE_1 LASTUPDATE_1 HIDDEN NONE;LASTEDITOR_1 LASTEDITOR_1 HIDDEN NONE;VERSIONNAME_1 VERSIONNAME_1 HIDDEN NONE;created_user_1 created_user_1 HIDDEN NONE;created_date_1 created_date_1 HIDDEN NONE;last_edited_user_1 last_edited_user_1 HIDDEN NONE;last_edited_date_1 last_edited_date_1 HIDDEN NONE;FID_Conduit_US_Jct_EL FID_Conduit_US_Jct_EL HIDDEN NONE;FID_Conduits_StartPoint FID_Conduits_StartPoint HIDDEN NONE;NAME NAME HIDDEN NONE;INLETNODE INLETNODE HIDDEN NONE;OUTLETNODE OUTLETNODE HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ORIG_FID_1 ORIG_FID_1 HIDDEN NONE;FID_Junctions FID_Junctions HIDDEN NONE;NAME_1 NAME_1 VISIBLE NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT_1 DESCRIPT_1 HIDDEN NONE;TAG_1 TAG_1 HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV_1 INVERTELEV_1 VISIBLE NONE;RIMELEV_1 RIMELEV_1 VISIBLE NONE;DEPTH DEPTH VISIBLE NONE;INITDEPTH INITDEPTH HIDDEN NONE;SURCHDEPTH SURCHDEPTH HIDDEN NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA_1 TOTCONAREA_1 HIDDEN NONE;IMPCONAREA_1 IMPCONAREA_1 HIDDEN NONE;UNITFLOW_1 UNITFLOW_1 HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE")

arcpy.analysis.Intersect("ssGravityMain_DS_MH_EL #;Conduit_DS_Jct_EL #", "GISModel_DS", "ALL", None, "INPUT")
arcpy.management.MakeFeatureLayer("GISModel_DS", "GISModel_DS_Layer", "abs(DOWNELEV - OUTOFFSET)>0.1", None, "OBJECTID OBJECTID HIDDEN NONE;SHAPE SHAPE HIDDEN NONE;FID_ssGravityMain_US_MH_EL FID_ssGravityMain_US_MH_EL HIDDEN NONE;FID_ssGravityMain_StartPoint FID_ssGravityMain_StartPoint HIDDEN NONE;FACILITYID FACILITYID VISIBLE NONE;FROMMH FROMMH VISIBLE NONE;TOMH TOMH HIDDEN NONE;MAINTYPE MAINTYPE HIDDEN NONE;DIAMETER DIAMETER HIDDEN NONE;MATERIAL MATERIAL HIDDEN NONE;PIPECLASS PIPECLASS HIDDEN NONE;UPJOINT UPJOINT HIDDEN NONE;DOWNJOINT DOWNJOINT HIDDEN NONE;INSTALLDATE INSTALLDATE HIDDEN NONE;SERIALNO_LOTNO SERIALNO_LOTNO HIDDEN NONE;UPELEV UPELEV VISIBLE NONE;DOWNELEV DOWNELEV HIDDEN NONE;SLOPE SLOPE HIDDEN NONE;VERIFICATION VERIFICATION HIDDEN NONE;MAINSHAPE MAINSHAPE HIDDEN NONE;LINERTYPE LINERTYPE HIDDEN NONE;LINEDYEAR LINEDYEAR HIDDEN NONE;ENABLED ENABLED HIDDEN NONE;ACTIVEFLAG ACTIVEFLAG HIDDEN NONE;OWNEDBY OWNEDBY HIDDEN NONE;MAINTBY MAINTBY HIDDEN NONE;SUMFLOW SUMFLOW HIDDEN NONE;WATERTYPE WATERTYPE HIDDEN NONE;EXTCOATING EXTCOATING HIDDEN NONE;ROCK ROCK HIDDEN NONE;LIFECYCLESTATUS LIFECYCLESTATUS HIDDEN NONE;WORKORDERID WORKORDERID HIDDEN NONE;SHEET SHEET HIDDEN NONE;PROJECT PROJECT HIDDEN NONE;CONTRACTEDBY CONTRACTEDBY HIDDEN NONE;ENGINEEREDBY ENGINEEREDBY HIDDEN NONE;HYPERLINK HYPERLINK HIDDEN NONE;COMMENTS COMMENTS HIDDEN NONE;LASTUPDATE LASTUPDATE HIDDEN NONE;LASTEDITOR LASTEDITOR HIDDEN NONE;VERSIONNAME VERSIONNAME HIDDEN NONE;NTG_ID NTG_ID HIDDEN NONE;NTG_DB NTG_DB HIDDEN NONE;NT_ID NT_ID HIDDEN NONE;CREEKCROSSING CREEKCROSSING HIDDEN NONE;created_user created_user HIDDEN NONE;created_date created_date HIDDEN NONE;last_edited_user last_edited_user HIDDEN NONE;last_edited_date last_edited_date HIDDEN NONE;MANUFACTURER MANUFACTURER HIDDEN NONE;Pipe_Length Pipe_Length HIDDEN NONE;ORIG_FID ORIG_FID HIDDEN NONE;FID_L3ssManhole FID_L3ssManhole HIDDEN NONE;FACILITYID_1 FACILITYID_1 VISIBLE NONE;FACILITYABBV FACILITYABBV VISIBLE NONE;FACILITYQS FACILITYQS HIDDEN NONE;MHTYPE MHTYPE VISIBLE NONE;LOCDESC LOCDESC HIDDEN NONE;LOCMEASURE LOCMEASURE HIDDEN NONE;RIMELEV RIMELEV VISIBLE NONE;INVERT INVERT VISIBLE NONE;HIGHELEV HIGHELEV VISIBLE NONE;INVERTELEV INVERTELEV HIDDEN NONE;CVTYPE CVTYPE HIDDEN NONE;WALLMAT WALLMAT HIDDEN NONE;BARRELDIA BARRELDIA HIDDEN NONE;INSTALLDATE_1 INSTALLDATE_1 HIDDEN NONE;LINED LINED HIDDEN NONE;LINEDYEAR_1 LINEDYEAR_1 HIDDEN NONE;CONDITION CONDITION HIDDEN NONE;VERIFICATION_1 VERIFICATION_1 HIDDEN NONE;GPSDATE GPSDATE HIDDEN NONE;ACCESSDIAMETER ACCESSDIAMETER HIDDEN NONE;ACCESSMATERIAL ACCESSMATERIAL HIDDEN NONE;GROUNDTYPE GROUNDTYPE HIDDEN NONE;ENABLED_1 ENABLED_1 HIDDEN NONE;ACTIVEFLAG_1 ACTIVEFLAG_1 HIDDEN NONE;OWNEDBY_1 OWNEDBY_1 HIDDEN NONE;MAINTBY_1 MAINTBY_1 HIDDEN NONE;SUMFLOW_1 SUMFLOW_1 HIDDEN NONE;FLOWDIR FLOWDIR HIDDEN NONE;WATERTYPE_1 WATERTYPE_1 HIDDEN NONE;PROJECT_1 PROJECT_1 HIDDEN NONE;SHEET_1 SHEET_1 HIDDEN NONE;CONTRACTEDBY_1 CONTRACTEDBY_1 HIDDEN NONE;ENGINEEREDBY_1 ENGINEEREDBY_1 HIDDEN NONE;LIFECYCLESTATUS_1 LIFECYCLESTATUS_1 HIDDEN NONE;SERIALNO_LOTNO_1 SERIALNO_LOTNO_1 HIDDEN NONE;HYPERLINK_1 HYPERLINK_1 HIDDEN NONE;COMMENTS_1 COMMENTS_1 HIDDEN NONE;POINT_X POINT_X HIDDEN NONE;POINT_Y POINT_Y HIDDEN NONE;LASTUPDATE_1 LASTUPDATE_1 HIDDEN NONE;LASTEDITOR_1 LASTEDITOR_1 HIDDEN NONE;VERSIONNAME_1 VERSIONNAME_1 HIDDEN NONE;created_user_1 created_user_1 HIDDEN NONE;created_date_1 created_date_1 HIDDEN NONE;last_edited_user_1 last_edited_user_1 HIDDEN NONE;last_edited_date_1 last_edited_date_1 HIDDEN NONE;FID_Conduit_US_Jct_EL FID_Conduit_US_Jct_EL HIDDEN NONE;FID_Conduits_StartPoint FID_Conduits_StartPoint HIDDEN NONE;NAME NAME HIDDEN NONE;INLETNODE INLETNODE HIDDEN NONE;OUTLETNODE OUTLETNODE HIDDEN NONE;DESCRIPT DESCRIPT HIDDEN NONE;TAG TAG HIDDEN NONE;LENGTH LENGTH HIDDEN NONE;ROUGHNESS ROUGHNESS HIDDEN NONE;INOFFSET INOFFSET HIDDEN NONE;OUTOFFSET OUTOFFSET HIDDEN NONE;INITFLOW INITFLOW HIDDEN NONE;FLOWLIMIT FLOWLIMIT HIDDEN NONE;ENTLOSSCO ENTLOSSCO HIDDEN NONE;EXITLOSSCO EXITLOSSCO HIDDEN NONE;AVGLOSSCO AVGLOSSCO HIDDEN NONE;SEEPAGE SEEPAGE HIDDEN NONE;FLAPGATE FLAPGATE HIDDEN NONE;XSECTION XSECTION HIDDEN NONE;GEOM1 GEOM1 HIDDEN NONE;GEOM2 GEOM2 HIDDEN NONE;GEOM3 GEOM3 HIDDEN NONE;GEOM4 GEOM4 HIDDEN NONE;BARRELS BARRELS HIDDEN NONE;TRANSECT TRANSECT HIDDEN NONE;SHAPECURVE SHAPECURVE HIDDEN NONE;CULVRTCODE CULVRTCODE HIDDEN NONE;CTRLRULES CTRLRULES HIDDEN NONE;SLOPE_1 SLOPE_1 HIDDEN NONE;MAXSPREAD MAXSPREAD HIDDEN NONE;TOTCONAREA TOTCONAREA HIDDEN NONE;IMPCONAREA IMPCONAREA HIDDEN NONE;UNITFLOW UNITFLOW HIDDEN NONE;MAXFLOW MAXFLOW HIDDEN NONE;TIMEMAXFLW TIMEMAXFLW HIDDEN NONE;MAXVELOCIT MAXVELOCIT HIDDEN NONE;CAPFLOW CAPFLOW HIDDEN NONE;CAPDEPTH CAPDEPTH HIDDEN NONE;MAXVOLUME MAXVOLUME HIDDEN NONE;FULLBOTH FULLBOTH HIDDEN NONE;HRSFULLUP HRSFULLUP HIDDEN NONE;FULLDOWN FULLDOWN HIDDEN NONE;FULLNORMAL FULLNORMAL HIDDEN NONE;HRSLIMITED HRSLIMITED HIDDEN NONE;LENGTHFACT LENGTHFACT HIDDEN NONE;DRY DRY HIDDEN NONE;SUBCRIT SUBCRIT HIDDEN NONE;SUPERCRIT SUPERCRIT HIDDEN NONE;NORMALLTD NORMALLTD HIDDEN NONE;INLETCNTRL INLETCNTRL HIDDEN NONE;IETAG IETAG HIDDEN NONE;HoytCommen HoytCommen VISIBLE NONE;Concate Concate HIDDEN NONE;ORIG_FID_1 ORIG_FID_1 HIDDEN NONE;FID_Junctions FID_Junctions HIDDEN NONE;NAME_1 NAME_1 VISIBLE NONE;X X HIDDEN NONE;Y Y HIDDEN NONE;DESCRIPT_1 DESCRIPT_1 HIDDEN NONE;TAG_1 TAG_1 HIDDEN NONE;INFLOWS INFLOWS HIDDEN NONE;TREATMENT TREATMENT HIDDEN NONE;INVERTELEV_1 INVERTELEV_1 VISIBLE NONE;RIMELEV_1 RIMELEV_1 VISIBLE NONE;DEPTH DEPTH VISIBLE NONE;INITDEPTH INITDEPTH HIDDEN NONE;SURCHDEPTH SURCHDEPTH HIDDEN NONE;PONDEDAREA PONDEDAREA HIDDEN NONE;BASEFLOW BASEFLOW HIDDEN NONE;BASEPATTRN BASEPATTRN HIDDEN NONE;TIMESERIES TIMESERIES HIDDEN NONE;SCALEFACTR SCALEFACTR HIDDEN NONE;AVGVALUE AVGVALUE HIDDEN NONE;PATTERN1 PATTERN1 HIDDEN NONE;PATTERN2 PATTERN2 HIDDEN NONE;PATTERN3 PATTERN3 HIDDEN NONE;PATTERN4 PATTERN4 HIDDEN NONE;HYDROGRAPH HYDROGRAPH HIDDEN NONE;SSAREA SSAREA HIDDEN NONE;TOTCONAREA_1 TOTCONAREA_1 HIDDEN NONE;IMPCONAREA_1 IMPCONAREA_1 HIDDEN NONE;UNITFLOW_1 UNITFLOW_1 HIDDEN NONE;AVGDEPTH AVGDEPTH HIDDEN NONE;MAXDEPTH MAXDEPTH HIDDEN NONE;MAXHGL MAXHGL HIDDEN NONE;TIMEMAXHGL TIMEMAXHGL HIDDEN NONE;REMAXDEPTH REMAXDEPTH HIDDEN NONE;MAXLATFLOW MAXLATFLOW HIDDEN NONE;MAXTOTFLOW MAXTOTFLOW HIDDEN NONE;TOTLATFLOW TOTLATFLOW HIDDEN NONE;TOTINFLOW TOTINFLOW HIDDEN NONE;FLOWERROR FLOWERROR HIDDEN NONE;HRSSURCHAR HRSSURCHAR HIDDEN NONE;MAXSURCHAR MAXSURCHAR HIDDEN NONE;MINDEPTHBR MINDEPTHBR HIDDEN NONE;HOURSFLOOD HOURSFLOOD HIDDEN NONE;MAXFLOODR MAXFLOODR HIDDEN NONE;TOTFLDVOL TOTFLDVOL HIDDEN NONE;MAXPONDED MAXPONDED HIDDEN NONE;CHANGELOG CHANGELOG HIDDEN NONE")
# Out:
# <Result 'GISModel_DS_Layer'>

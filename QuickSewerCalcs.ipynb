# %%
#elevation interpolation

pipediam = 8
Upstream = 1058
Downstream = 1056.40002441
PipeLengthFt = 525
LengthAlongFlowline = 5

Slope = round(((Upstream-Downstream)/PipeLengthFt)*100, 3)
print(str(Slope)+"% slope")

ElevationAtStation = round((Upstream-Slope/100*LengthAlongFlowline), 3)

print("Elevation "+str(LengthAlongFlowline)+" feet from upstream is "+ str(ElevationAtStation)+" ft")

PipeTapElevation = round(ElevationAtStation+pipediam/12*0.8, 2)

print("Approximate Pipe Tap Elevation is "+str(PipeTapElevation))
# Out:
# 0.305% slope
# Elevation 5 feet from upstream is 1057.985 ft
# Approximate Pipe Tap Elevation is 1058.52

# %%
#proposed extension calculations for proposed site at 6th & GWW to connect east to MH 016
Downstream = 1056.40002441
Proposed_Length_ft = 525
DS_pipediam = 8
Proposed_pipediam = 8
LowGroundElevation = 1058
LowestElevationStation = 3 #station along proposed pipe from upstream to downstream

if Proposed_pipediam == 8:
    minimum_slope = 0.64
    
Reqired_minimum_US_invert = Downstream+(Proposed_Length_ft*minimum_slope/100)

PipeTopElevation = round(Reqired_minimum_US_invert+pipediam/12)
pipecoverdepth = round(LowGroundElevation-PipeTopElevation, 2)

if pipecoverdepth <30/12:
    print("pipe does not meet minimum cover depth standards")
elif pipecoverdepth >20:
    print("pipe does not meet minimum cover depth standards")
else:
    print("pipe meets cover depth standards")
    
print("Required minimum invert depth is "+str(round(Reqired_minimum_US_invert,2))+ " to meet minimum slope of " +str(minimum_slope)+ "% for "+str(Proposed_pipediam)+" in pipe")
if Proposed_Length_ft > 400:
    print("MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis")
else:
    pass

if pipecoverdepth < 2.5:
    print(str(0-pipecoverdepth) + " feet /"+str(round(0-pipecoverdepth*12, 1)) + " in of fill would be required to meet minimum pipe depth requirement at a station "+str(LowestElevationStation) + " ft along the proposed pipe")
elif pipecoverdepth >= 30/12 and pipecoverdepth <= 20:
    print(str(pipecoverdepth) + " feet /"+str(round(pipecoverdepth*12, 1)) + "in minimum and maximum cover depth requirements are met")
else:
    print("max cover depth exceeded")
# Out:
# pipe does not meet minimum cover depth standards
# Required minimum invert depth is 1059.76 to meet minimum slope of 0.64% for 8 in pipe
# MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis
# 2 feet /24 in of fill would be required to meet minimum pipe depth requirement at a station 3 ft along the proposed pipe

# %%
#proposed extension calculations proposed site at 6th & GWW to manhole 115 at overland dr and GWW leg to corner from 115
Downstream = 994.843
Proposed_Length_ft = 140
DS_pipediam = 8
Proposed_pipediam = 8
LowGroundElevation = 1001
LowestElevationStation = 1 #station along proposed pipe from upstream to downstream

if Proposed_pipediam == 8:
    minimum_slope = 0.64
    
Reqired_minimum_US_invert = Downstream+(Proposed_Length_ft*minimum_slope/100)

PipeTopElevation = round(Reqired_minimum_US_invert+pipediam/12)
pipecoverdepth = round(LowGroundElevation-PipeTopElevation, 2)

if pipecoverdepth <30/12:
    print("pipe does not meet minimum cover depth standards")
elif pipecoverdepth >20:
    print("pipe does not meet minimum cover depth standards")
else:
    print("pipe meets cover depth standards")
    
print("Required minimum invert depth is "+str(round(Reqired_minimum_US_invert,2))+ " to meet minimum slope of " +str(minimum_slope)+ "% for "+str(Proposed_pipediam)+" in pipe")
if Proposed_Length_ft > 400:
    print("MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis")
else:
    pass

if pipecoverdepth < 2.5:
    print(str(0-pipecoverdepth) + " feet /"+str(round(0-pipecoverdepth*12, 1)) + " in of fill would be required to meet minimum pipe depth requirement at a station "+str(LowestElevationStation) + " ft along the proposed pipe")
elif pipecoverdepth >= 30/12 and pipecoverdepth <= 20:
    print(str(pipecoverdepth) + " feet /"+str(round(pipecoverdepth*12, 1)) + "in minimum and maximum cover depth requirements are met")
else:
    print("max cover depth exceeded")
# Out:
# pipe meets cover depth standards
# Required minimum invert depth is 995.74 to meet minimum slope of 0.64% for 8 in pipe
# 5 feet /60in minimum and maximum cover depth requirements are met

# %%
#proposed extension calculations proposed site at 6th & GWW to manhole 115 at overland dr and GWW leg to corner from 115
Downstream = 994.843
Proposed_Length_ft = 140+767
DS_pipediam = 8
Proposed_pipediam = 8
LowGroundElevation = 1030
LowestElevationStation = 188 #station along proposed pipe from upstream to downstream

if Proposed_pipediam == 8:
    minimum_slope = 0.64
    
Reqired_minimum_US_invert = Downstream+(Proposed_Length_ft*minimum_slope/100)

PipeTopElevation = round(Reqired_minimum_US_invert+pipediam/12)
pipecoverdepth = round(LowGroundElevation-PipeTopElevation, 2)

if pipecoverdepth <30/12:
    print("pipe does not meet minimum cover depth standards")
elif pipecoverdepth >20:
    print("pipe does not meet minimum cover depth standards")
else:
    print("pipe meets cover depth standards")
    
print("Required minimum invert depth is "+str(round(Reqired_minimum_US_invert,2))+ " to meet minimum slope of " +str(minimum_slope)+ "% for "+str(Proposed_pipediam)+" in pipe")
if Proposed_Length_ft > 400:
    print("MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis")
else:
    pass

if pipecoverdepth < 2.5:
    print(str(0-pipecoverdepth) + " feet /"+str(round(0-pipecoverdepth*12, 1)) + " in of fill would be required to meet minimum pipe depth requirement at a station "+str(LowestElevationStation) + " ft along the proposed pipe")
elif pipecoverdepth >= 30/12 and pipecoverdepth <= 20:
    print(str(pipecoverdepth) + " feet /"+str(round(pipecoverdepth*12, 1)) + "in minimum and maximum cover depth requirements are met")
else:
    print("max cover depth exceeded")
# Out:
# pipe does not meet minimum cover depth standards
# Required minimum invert depth is 1000.65 to meet minimum slope of 0.64% for 8 in pipe
# MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis
# max cover depth exceeded

# %%
#proposed extension calculations proposed site at 6th & GWW south to manhole 518
Downstream = 1004.19
Proposed_Length_ft = 800+128
DS_pipediam = 8
Proposed_pipediam = 8
LowGroundElevation = 1054
LowestElevationStation = 250 #station along proposed pipe from upstream to downstream

if Proposed_pipediam == 8:
    minimum_slope = 0.64
    
Reqired_minimum_US_invert = Downstream+(Proposed_Length_ft*minimum_slope/100)

PipeTopElevation = round(Reqired_minimum_US_invert+pipediam/12)
pipecoverdepth = round(LowGroundElevation-PipeTopElevation, 2)

if pipecoverdepth <30/12:
    print("pipe does not meet minimum cover depth standards")
elif pipecoverdepth >20:
    print("pipe does not meet minimum cover depth standards")
else:
    print("pipe meets cover depth standards")
    
print("Required minimum invert depth is "+str(round(Reqired_minimum_US_invert,2))+ " to meet minimum slope of " +str(minimum_slope)+ "% for "+str(Proposed_pipediam)+" in pipe")
if Proposed_Length_ft > 400:
    print("MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis")
else:
    pass

if pipecoverdepth < 2.5:
    print(str(0-pipecoverdepth) + " feet /"+str(round(0-pipecoverdepth*12, 1)) + " in of fill would be required to meet minimum pipe depth requirement at a station "+str(LowestElevationStation) + " ft along the proposed pipe")
elif pipecoverdepth >= 30/12 and pipecoverdepth <= 20:
    print(str(pipecoverdepth) + " feet /"+str(round(pipecoverdepth*12, 1)) + "in minimum and maximum cover depth requirements are met")
else:
    print("max cover depth exceeded")
# Out:
# pipe does not meet minimum cover depth standards
# Required minimum invert depth is 1010.13 to meet minimum slope of 0.64% for 8 in pipe
# MH spacing is 400' max, this exceeds that spacing and will need an additional manhole. Greater spacing may be approved on a case by case basis
# max cover depth exceeded

# %%
#calculate grade of a 4 inch sewer service based on MSFE and downstream sewer elevation

MSFE = 1062

pipediam = 8
Upstream = MSFE-3
PipeLengthFt = 199


Slope = round(((Upstream-PipeTapElevation)/PipeLengthFt)*100, 3)

print(str(Slope)+"% Average slope")
if Slope< 2:
    print("does not meet minimum slope for 4 inch service")
else:
    print("meets minimum slope for 4 inch service")
    
if PipeLengthFt > 200:
    print("service maximum length is exceeded")
# Out:
# 0.241% Average slope
# does not meet minimum slope for 4 inch service

# %%
#check lowest ground elevations over pipe
LowGroundElevation = 1061

PipeTopElevation = round(ElevationAtStation+pipediam/12, 2)

pipecoverdepth = round(LowGroundElevation-PipeTopElevation, 2)

print(str(pipecoverdepth) + " feet /"+str(round(pipecoverdepth*12, 1)) + " inches to top of pipe")

if pipecoverdepth <30/12:
    print("pipe does not meet minimum cover depth standards")
elif pipecoverdepth >20:
    print("pipe does not meet minimum cover depth standards")
else:
    print("pipe meets cover depth standards")
# Out:
# 2.52 feet /30.2 inches to top of pipe
# pipe meets cover depth standards

# %%
#calculate MSO Design Requirement status (https://lawrenceks.org/wp-content/uploads/2020/02/MSO-Design-Criteria.pdf)
pipetype = "main"

#main or service

MSODesign = r'https://lawrenceks.org/wp-content/uploads/2020/02/MSO-Design-Criteria.pdf'


if pipediam == 4:
    if Slope >= 2 and Slope <=8.344:
        print ("meets minimum design slope for 4 in service pipe")
    elif Slope < 2:
        print("pipe does not meet MSO Design criteria for 4 in service minimum slope")
    elif Slope > 8.344:
        print ("pipe does not meet MSO Design criteria for maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for 4 in service in pipe")    
        
elif pipediam == 6:
    if Slope >= 1 and Slope <=8.344:
        print ("meets minimum design slope for 6 in service pipe")
    elif Slope < 1:
        print("pipe does not meet MSO Design criteria for 6 in service minimum slope")
    elif Slope > 8.344:
        print ("pipe does not meet MSO Design criteria for maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for 6 in service in pipe")           
        
elif pipediam == 8:
    if Slope >= 1 and Slope <=8.344: 
        print ("meets minimum slope for design flow of 70 gpm")
    elif Slope>=0.8 and Slope<1:
        print ("meets minimum slope for design flow of 71-141 gpm")
    elif Slope>=0.64 and Slope<0.8:
        print ("meets minimum slope for design flow of 71-141 gpm")
    elif Slope > 8.344:
        print ("pipe does not meet MSO Design criteria for maximum slope")
    elif Slope <0.64:
        print ("pipe does not meet MSO Design criteria minimum slope for 8 inch pipe")
    else:
        print ("pipe does not meet MSO Design criteria")
elif pipediam == 10:
    if Slope >= 0.248 and Slope <=6.197:
        print ("meets minimum design slope for 10 in pipe")
    elif Slope < 0.248:
        print("pipe does not meet MSO Design criteria for 10 in minimum slope")
    elif Slope > 6.197:
        print ("pipe does not meet MSO Design criteria for 10 in maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for a 10 in pipe")    
elif pipediam == 12:
    if Slope >= 0.194 and Slope <=4.860:
        print ("meets minimum design slope for 10 in pipe")
    elif Slope < 0.194:
        print("pipe does not meet MSO Design criteria for 12 in minimum slope")
    elif Slope > 4.860:
        print ("pipe does not meet MSO Design criteria for 12 in maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for a 12 in pipe")    
        
elif pipediam == 15:
    if Slope >= 0.144 and Slope <=3.609:
        print ("meets minimum design slope for 10 in pipe")
    elif Slope < 0.144:
        print("pipe does not meet MSO Design criteria for 15 in minimum slope")
    elif Slope > 3.609:
        print ("pipe does not meet MSO Design criteria for 15 in maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for a 15 in pipe")    
        
elif pipediam == 18:
    if Slope >= 0.113 and Slope <=2.830:
        print ("meets minimum design slope for 10 in pipe")
    elif Slope < 0.113:
        print("pipe does not meet MSO Design criteria for 18 in minimum slope")
    elif Slope > 2.830:
        print ("pipe does not meet MSO Design criteria for 18 in maximum slope")
    else:
        print ("pipe does not meet MSO Design criteria for a 18 in pipe")           
else:
    print("pipe is not 4, 6, 8, 10, 15, or 18 inches")
        

if Slope > 15: 
    if PipeLengthFt > 100:
        print("special provisions shall be made to anchor the pipe")
    else:
        print("anchoring not required because pipe length is shorter than 100 ft")
else:
    print("anchoring is not required because slope is not greater than 15%")
# Out:
# pipe does not meet MSO Design criteria minimum slope for 8 inch pipe
# anchoring is not required because slope is not greater than 15%

# %% [markdown]
# This cell is markdown of text copied, pated and formatted from MSO Design Standards, the basis for calculations in this notebook:
#
# Pipe Slope:
#
# Pipe slope shall be as follows for eight (8) inch diameter sewer mains:
# Calculated Design Flow    Minimum Slope
# (gpm)                     (%)
# 0-70                      1.00%
# 71-141                    0.80%
# 142 or more               0.64%
#
# For pipe larger than eight (8) inches in diameter the slope shall provide a minimum velocity of two (2) feet per second when flowing half full.
# The following table indicates the minimum permissible slopes for this Condition.
#
# Minimum Pipe Slopes -
# Pipe Diameter   Hydraulic Radius    Minimum Slope
# (in)            (ft)                (%)
# 10              0.208               0.248%
# 12              0.250               0.194%
# 15              0.313               0.144%
# 18              0.375               0.113%
#
# All public sewers should be designed such that the mean velocity does not exceed ten (10) feet per second when flowing full.
# The following table indicates the maximum permissible slopes for this condition.
#
# Maximum Pipe Slopes -
# Pipe Diameter   Hydraulic Radius    Maximum Slope
# 8               0.167               8.344%
# 10              0.208               6.197%
# 12              0.250               4.860%
# 15              0.313               3.609%
# 18              0.375               2.830%
#
# The minimum slope for a six (6) inch service line shall be 1.00%.
#
# The minimum slope for a four (4) inch service line shall be 2.00%.
#
# For all buildings and/or lots to be serviced by the sewer main minimum serviceable floor elevations (MSFE) shall be provided.
# A distance of three feet between the floor elevation and the flow line of the main at the connection is considered the minimum vertical clearance provided for connection.
# This clearance must be increased to account for service line length, depth of the lot, and other site-specific circumstances.
#
# Minimum Cover: A minimum of thirty (30) inches of cover is required over the top of the main and service stubs in all locations.
#
# Pipe Depth: The depth of sewers generally shall be limited to twenty (20) feet as measured from flowline of pipe to finished grade.
